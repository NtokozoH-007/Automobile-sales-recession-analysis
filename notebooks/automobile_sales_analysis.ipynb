# %% [markdown]
# # 🚗 Automobile Sales and Recession Impact Analysis
#
# ## Business Intelligence Portfolio Project
#
# **Author:** Ntokozo Hlongwane
#
# ---
#
# ## Project Introduction
#
# The automobile industry is highly sensitive to changes in economic conditions. During periods of recession, consumers often reduce discretionary spending, postpone vehicle purchases, and prioritize essential expenses. These behavioral changes directly influence automobile manufacturers, dealerships, and marketing strategies.
#
# This project investigates historical automobile sales data to understand how economic recessions affect vehicle sales performance, advertising expenditure, unemployment, and consumer confidence.
#
# Using Python and modern data visualization techniques, this analysis aims to identify meaningful trends and transform raw data into actionable business insights that can support strategic decision-making.
#
# This portfolio project demonstrates practical skills in exploratory data analysis (EDA), business intelligence, and data storytelling using Python.

# %% [markdown]
# ## Project Objectives
#
# The primary objectives of this project are to:
#
# - Understand historical automobile sales trends.
# - Compare sales performance during recession and non-recession periods.
# - Identify which vehicle categories are most affected during recessions.
# - Explore the relationship between unemployment and automobile sales.
# - Analyze changes in advertising expenditure during economic downturns.
# - Visualize regional sales performance using an interactive geographic map.
# - Provide business recommendations based on data-driven insights.

# %% [markdown]
# ## Business Questions
#
# This project seeks to answer the following business questions:
#
# 1. How have automobile sales changed over time?
# 2. How do recession periods compare with non-recession periods?
# 3. Which vehicle types experience the greatest decline during recessions?
# 4. Does unemployment significantly influence vehicle sales?
# 5. How does advertising expenditure change during recession periods?
# 6. Which regions generate the highest sales during recessions?
# 7. What strategies can automobile companies implement to reduce the impact of future recessions?

# %% [markdown]
# ## Project Workflow
#
# The analysis follows the standard data analytics workflow:
#
# 1. Import Python libraries
# 2. Load the dataset
# 3. Explore the dataset
# 4. Assess data quality
# 5. Clean and prepare the data
# 6. Perform exploratory data analysis
# 7. Create visualizations
# 8. Analyze recession impacts
# 9. Build an interactive Folium map
# 10. Summarize findings
# 11. Develop business recommendations
# 12. Draw conclusions

# %% [markdown]
# ## Technologies Used
#
# The following Python libraries are used throughout this analysis:
#
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Folium
# - Jupyter Notebook

# %% [markdown]
# ## Dataset
#
# This analysis uses an educational automobile sales dataset containing historical sales information across different years, vehicle categories, advertising expenditure, unemployment rates, consumer confidence measures, and regional sales performance.
#
# The dataset is used to evaluate the effect of economic recessions on automobile sales and identify patterns that can support business decision-making.

# %% [markdown]
# ## Expected Deliverables
#
# By the end of this project, the following outputs will be produced:
#
# - Cleaned dataset
# - Exploratory Data Analysis (EDA)
# - Professional visualizations using Matplotlib and Seaborn
# - Interactive geographic map using Folium
# - Business insights
# - Strategic recommendations
# - Executive summary

# %% [markdown]
# ## Next Step
#
# The next stage of the project involves importing the required Python libraries and loading the dataset for exploration and analysis.

# %% [markdown]
# ## Loading the Dataset
#
# The automobile sales dataset is loaded into a Pandas DataFrame for inspection, cleaning, and analysis.
#
# The dataset is stored in the `data` folder of the project repository.

# %%
from pathlib import Path

project = Path(r"\\sunrga.stb.sun.ac.za\home\\ebw\21753520\Documents\Automobile-sales-recession-analysis")

print(project.exists())
# Out:
# True

# %%
csv_file = project / "Data" / "automobile_sales.csv"

print(csv_file)
print(csv_file.exists())
# Out:
# \\sunrga.stb.sun.ac.za\home\ebw\21753520\Documents\Automobile-sales-recession-analysis\Data\automobile_sales.csv
# True

# %%
import pandas as pd

df = pd.read_csv(csv_file)

print("Dataset loaded successfully!")
print(df.shape)

df.head()
# Out:
# Dataset loaded successfully!
# (2112, 15)
#          Date  Year Month  Recession  Consumer_Confidence  Seasonality_Weight  \
# 0  1980-01-31  1980   Jan          1               108.24                0.45
# 1  1980-01-31  1980   Jan          1               108.24                0.45
# 2  1980-01-31  1980   Jan          1               108.24                0.36
# 3  1980-01-31  1980   Jan          1               108.24                0.38
# 4  1980-02-29  1980   Feb          1                98.75                0.46
#
#    Price  Advertising_Expenditure  Competition    GDP  Growth_Rate  \
# 0  27704                   1417.5            7  60.22         0.01
# 1  77270                    763.7            7  60.22         0.01
# 2  19665                   1417.5            7  60.22         0.01
# 3  36986                   1417.5            7  60.22         0.01
# 4  26609                   2773.4            4  45.99        -0.31
#
# ...

# %% [markdown]
# ## Data Understanding
#
# This section examines the structure, columns, data types, missing values, duplicate records, and summary statistics of the automobile sales dataset before cleaning and analysis.

# %%
df.head()
# Out:
#          Date  Year Month  Recession  Consumer_Confidence  Seasonality_Weight  \
# 0  1980-01-31  1980   Jan          1               108.24                0.45
# 1  1980-01-31  1980   Jan          1               108.24                0.45
# 2  1980-01-31  1980   Jan          1               108.24                0.36
# 3  1980-01-31  1980   Jan          1               108.24                0.38
# 4  1980-02-29  1980   Feb          1                98.75                0.46
#
#    Price  Advertising_Expenditure  Competition    GDP  Growth_Rate  \
# 0  27704                   1417.5            7  60.22         0.01
# 1  77270                    763.7            7  60.22         0.01
# 2  19665                   1417.5            7  60.22         0.01
# 3  36986                   1417.5            7  60.22         0.01
# 4  26609                   2773.4            4  45.99        -0.31
#
#    unemployment_rate  Automobile_Sales     Vehicle_Type      City
# ...

# %%
df.columns.tolist()
# Out:
# ['Date',
#  'Year',
#  'Month',
#  'Recession',
#  'Consumer_Confidence',
#  'Seasonality_Weight',
#  'Price',
#  'Advertising_Expenditure',
#  'Competition',
#  'GDP',
#  'Growth_Rate',
#  'unemployment_rate',
#  'Automobile_Sales',
#  'Vehicle_Type',
#  'City']

# %%
df.columns.tolist()
# Out:
# ['Date',
#  'Year',
#  'Month',
#  'Recession',
#  'Consumer_Confidence',
#  'Seasonality_Weight',
#  'Price',
#  'Advertising_Expenditure',
#  'Competition',
#  'GDP',
#  'Growth_Rate',
#  'unemployment_rate',
#  'Automobile_Sales',
#  'Vehicle_Type',
#  'City']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2112 entries, 0 to 2111
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     2112 non-null   object
#  1   Year                     2112 non-null   int64
#  2   Month                    2112 non-null   object
#  3   Recession                2112 non-null   int64
#  4   Consumer_Confidence      2112 non-null   float64
#  5   Seasonality_Weight       2112 non-null   float64
#  6   Price                    2112 non-null   int64
#  7   Advertising_Expenditure  2112 non-null   float64
#  8   Competition              2112 non-null   int64
#  9   GDP                      2112 non-null   float64
#  10  Growth_Rate              2112 non-null   float64
#  11  unemployment_rate        2112 non-null   float64
#  12  Automobile_Sales         2112 non-null   float64
#  13  Vehicle_Type             2112 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Date                       0
# Year                       0
# Month                      0
# Recession                  0
# Consumer_Confidence        0
# Seasonality_Weight         0
# Price                      0
# Advertising_Expenditure    0
# Competition                0
# GDP                        0
# Growth_Rate                0
# unemployment_rate          0
# Automobile_Sales           0
# Vehicle_Type               0
# City                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().T
# Out:
#                           count          mean           std       min  \
# Year                     2112.0   2001.520833     12.535031   1980.00
# Recession                2112.0      0.224432      0.417306      0.00
# Consumer_Confidence      2112.0    101.210890     10.634092     73.90
# Seasonality_Weight       2112.0      0.737756      0.286092      0.25
# Price                    2112.0  41469.506155  21388.409141  15001.00
# Advertising_Expenditure  2112.0   2879.743655   1175.338324    494.20
# Competition              2112.0      6.118845      1.964292      3.00
# GDP                      2112.0     40.205748     16.291271     12.51
# Growth_Rate              2112.0     -0.237074      0.859691     -4.23
# unemployment_rate        2112.0      2.441525      1.108472      1.00
# Automobile_Sales         2112.0   3164.160511   3640.137399     40.00
#
#                               25%        50%         75%       max
# ...

# %%
df.describe(include="object").T
# Out:
#              count unique         top freq
# Date          2112    528  2022-04-30    5
# Month         2112     12         Apr  188
# Vehicle_Type  2112      5      Sports  431
# City          2112      4    New York  586

# %%
df.columns.tolist()
# Out:
# ['Date',
#  'Year',
#  'Month',
#  'Recession',
#  'Consumer_Confidence',
#  'Seasonality_Weight',
#  'Price',
#  'Advertising_Expenditure',
#  'Competition',
#  'GDP',
#  'Growth_Rate',
#  'unemployment_rate',
#  'Automobile_Sales',
#  'Vehicle_Type',
#  'City']

# %% [markdown]
# ## Data Quality Assessment
#
# Before performing any analysis, the dataset is evaluated to identify potential quality issues that could affect the accuracy of the results.
#
# The assessment includes:
#
# - Dataset dimensions
# - Data types
# - Missing values
# - Duplicate records
# - Summary statistics
# - Distribution of categorical variables
#
# A thorough understanding of the dataset ensures that subsequent analyses are based on reliable and consistent information.
